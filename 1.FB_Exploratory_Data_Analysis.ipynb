# %% [markdown]
# <p style="font-size:32px;text-align:center"> <b>Social network Graph Link Prediction - Facebook Challenge</b> </p>

# %% [markdown]
# <img src = '2.gif' length = '200' width = '9000' >

# %% [markdown]
# ### Problem statement:
# Given a directed social graph, have to predict missing links to recommend users (Link Prediction in graph)

# %% [markdown]
# ### Problem statement:
# Given a directed social graph, have to predict missing links to recommend users (Link Prediction in graph)
# ### Data Overview
# Taken data from facebook's recruting challenge on kaggle https://www.kaggle.com/c/FacebookRecruiting
# data contains two columns source and destination eac edge in graph
#     - Data columns (total 2 columns):
#     - source_node         int64
#     - destination_node    int64
#
# ### Mapping the problem into supervised learning problem:
# - Mapping this to a binary classification task with 0 implying an absence of an edge and 1 representing the presence as y_i's.Our most important objective here is to get features from a certain pair of vertices(u_i,u_j) such that they can help us in predicting the presence/absence of an edge.A simple feature could be number of common friends to u_i and u_j which is highly indicative of an edge between them and  and trained ml model based on these features to predict link. Generated training samples of good and bad links from given directed graph and for each link got some features like no of followers, is he followed back, page rank, katz score, adar index, some svd fetures of adj matrix, some weight features etc. and trained ml model based on these features to predict link.
# - The reference papers I have referred to:
#     - https://kaggle2.blob.core.windows.net/forum-message-attachments/2594/supervised_link_prediction.pdf

# %% [markdown]
# ### Mapping the problem into supervised learning problem:
# - Mapping this to a binary classification task with 0 implying an absence of an edge and 1 representing the presence as y_i's.Our most important objective here is to get features from a certain pair of vertices(u_i,u_j) such that they can help us in predicting the presence/absence of an edge.A simple feature could be number of common friends to u_i and u_j which is highly indicative of an edge between them and  and trained ml model based on these features to predict link. Generated training samples of good and bad links from given directed graph and for each link got some features like no of followers, is he followed back, page rank, katz score, adar index, some svd fetures of adj matrix, some weight features etc. and trained ml model based on these features to predict link.
# - The reference papers I have referred to:
#     - https://kaggle2.blob.core.windows.net/forum-message-attachments/2594/supervised_link_prediction.pdf

# %% [markdown]
# ### Business objectives and constraints:
# - No low-latency requirement.
# - Probability of prediction is useful to reccommend highest probability link
# - We got to suggest connections which are most likely to be correct and we should try and not miss out at any connections
#
# ### Performance metric for supervised learning:
# - Both precision and recall is important so F1 score is good choice
# - Confusion matrix

# %% [markdown]
# ### Performance metric for supervised learning:
# - Both precision and recall is important so F1 score is good choice
# - Confusion matrix

# %% [markdown]
# # WHY to choose this Problem

# %% [markdown]
# <p>Facebook did a recruiting challenge some times back on Kaggle where they gave this dataset.Here we are trying to find missing links which we will use for recommending friends or followers or in general recommending connections.Facebook created this to sove their business problem.The dataset is fairly reasonably sized to get a feel and understanding of how Network Analaysis works with Machine Learning in real world scenarios.Facebook has given this problem based on directed graphs which represent users on social network.<p>

# %% [markdown]
# <h3>NOTE:-</h3>
# - we are given the data at a particular snapshot i.e at a certain time 't' all the edges and vertices are mentioned.

# %% [markdown]
# # Importing libraries

# %%
#importing all the important libraries 
import warnings
warnings.filterwarnings('ignore')

import csv
import pandas as pd#to create dataframes
import numpy as np #to to matrix and arithmetic calculations
import datetime#convert to unix time
import time #convert to unix time
import matplotlib.pyplot as plt#to plot the graphs
import seaborn as sns#plots specification enhancement
from matplotlib import rcParams#size of the plots
import math
import os
from sklearn.cluster import MiniBatchKMeans, KMeans#clustering
import pickle#to read and write files
import xgboost as xgb#gradient boosting
import networkx as nx
#library in python used for analysing the graphs
import pdb
import warnings

# %%
#reading graph
if not os.path.isfile('after_eda/train_woheader.csv'):
    traincsv = pd.read_csv('train.csv')
    print(traincsv[traincsv.isna().any(1)])
    print(traincsv.info())#information about the dataset
    print("Number of duplicate entries: ",sum(traincsv.duplicated()))#calculating sum of all duplicated values
    traincsv.to_csv('after_eda/train_woheader.csv',header=False,index=False)#saving to a csv file
    print("saved the graph into file")
else:
    g=nx.read_edgelist('after_eda/train_woheader.csv',delimiter=',',create_using=nx.DiGraph(),nodetype=int)
    #Digraph tells us about the directed graph
    print(nx.info(g))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 1862220
# Number of edges: 9437519
# Average in degree:   5.0679
# Average out degree:   5.0679

# %% [markdown]
# > Displaying a sub graph

# %%
#to display the graph we need to create a subgraph with less rows for analyzing it
pd.read_csv('after_eda/train_woheader.csv',nrows = 50).to_csv('train_woheader_sample.csv',header = False,index = False)
#this creates sample file with 50 rows only
subgraph = nx.read_edgelist('train_woheader_sample.csv',delimiter = ',',create_using = nx.DiGraph(),nodetype = int)
#Digraph tells about the directed graph
pos=nx.spring_layout(subgraph)
nx.draw(subgraph,pos,node_size = 200,node_color='#A0CBE2',edge_color='#00bb5e',width=2,edge_cmap=plt.cm.Blues,with_labels=True)
plt.savefig("graph_sample.pdf")
print(nx.info(subgraph))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 66
# Number of edges: 50
# Average in degree:   0.7576
# Average out degree:   0.7576

# %% [markdown]
# # 1. Exploratory Data Analysis

# %%
# No of Unique persons 
print("The number of unique persons",len(g.nodes()))
# Out:
# The number of unique persons 1862220

# %% [markdown]
# ## 1.1 No of followers for each person

# %%
#Number of followers for each user means indegree of a node
indegree_dist = list(dict(g.in_degree()).values())
indegree_dist.sort()#sorts the values of indegree for plotting
sns.set_style('darkgrid')
plt.figure(figsize = (15,6))
plt.plot(indegree_dist)
plt.xlabel('Index number',fontsize=15)
plt.ylabel('Number of followers',fontsize=15)
plt.show()

# %%
indegree_dist = list(dict(g.in_degree()).values())
indegree_dist.sort()
sns.set_style('darkgrid')
plt.figure(figsize = (15,6))
plt.plot(indegree_dist[0:1500000])
plt.xlabel('Index number',fontsize=15)
plt.ylabel('Number of followers',fontsize=15)
plt.show()

# %%
plt.figure(figsize = (15,6))
plt.boxplot(indegree_dist,)
plt.ylabel('Number of followers',fontsize = 15)
plt.show()

# %%
### 90-100 percentile
for i in range(0,11):
    print(90+i,'percentile value is',np.percentile(indegree_dist,90+i))
# Out:
# 90 percentile value is 12.0
# 91 percentile value is 13.0
# 92 percentile value is 14.0
# 93 percentile value is 15.0
# 94 percentile value is 17.0
# 95 percentile value is 19.0
# 96 percentile value is 21.0
# 97 percentile value is 24.0
# 98 percentile value is 29.0
# 99 percentile value is 40.0
# 100 percentile value is 552.0

# %% [markdown]
# 99% of data having followers of 40 only.

# %%
### 99-100 percentile
for i in range(10,110,10):
    print(99+(i/100),'percentile value is',np.percentile(indegree_dist,99+(i/100)))
# Out:
# 99.1 percentile value is 42.0
# 99.2 percentile value is 44.0
# 99.3 percentile value is 47.0
# 99.4 percentile value is 50.0
# 99.5 percentile value is 55.0
# 99.6 percentile value is 61.0
# 99.7 percentile value is 70.0
# 99.8 percentile value is 84.0
# 99.9 percentile value is 112.0
# 100.0 percentile value is 552.0

# %%
# %matplotlib inline
warnings.filterwarnings('ignore')
sns.set_style('ticks')
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.distplot(indegree_dist, color='#16A085')
plt.xlabel('PDF of Indegree')
sns.despine()
#plt.show()

# %% [markdown]
# ## 1.2 No of people each person is following

# %%
#Number of users each user is following basically tells us about the outdegree of each node
outdegree_dist = list(dict(g.out_degree()).values())
outdegree_dist.sort()
sns.set_style('darkgrid')
plt.figure(figsize = (15,6))
plt.plot(outdegree_dist)
plt.xlabel('Index number',fontsize=15)
plt.ylabel('Number of People a user folllows',fontsize=15)
plt.show()

# %%
plt.figure(figsize = (15,6))
plt.boxplot(outdegree_dist,)
plt.ylabel('Number of people a user follows',fontsize = 15)
plt.show()

# %%
outdegree_dist = list(dict(g.out_degree()).values())
outdegree_dist.sort()
sns.set_style('darkgrid')
plt.figure(figsize = (15,6))
plt.plot(outdegree_dist[0:1500000])
plt.xlabel('Index number',fontsize=15)
plt.ylabel('Number of people a user follows',fontsize=15)
plt.show()

# %%
### 90-100 percentile
for i in range(0,11):
    print(90+i,'percentile value is',np.percentile(outdegree_dist,90+i))
# Out:
# 90 percentile value is 12.0
# 91 percentile value is 13.0
# 92 percentile value is 14.0
# 93 percentile value is 15.0
# 94 percentile value is 17.0
# 95 percentile value is 19.0
# 96 percentile value is 21.0
# 97 percentile value is 24.0
# 98 percentile value is 29.0
# 99 percentile value is 40.0
# 100 percentile value is 1566.0

# %%
### 99-100 percentile
for i in range(10,110,10):
    print(99+(i/100),'percentile value is',np.percentile(outdegree_dist,99+(i/100)))
# Out:
# 99.1 percentile value is 42.0
# 99.2 percentile value is 45.0
# 99.3 percentile value is 48.0
# 99.4 percentile value is 52.0
# 99.5 percentile value is 56.0
# 99.6 percentile value is 63.0
# 99.7 percentile value is 73.0
# 99.8 percentile value is 90.0
# 99.9 percentile value is 123.0
# 100.0 percentile value is 1566.0

# %%
sns.set_style('ticks')
warnings.filterwarnings('ignore')
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.distplot(outdegree_dist, color='#16A085')
plt.xlabel('PDF of Outdegree')
sns.despine()

# %%
print('No of persons those are not following anyone are' ,sum(np.array(outdegree_dist)==0),'and % is',
                                sum(np.array(outdegree_dist)==0)*100/len(outdegree_dist) )
# Out:
# No of persons those are not following anyone are 274512 and % is 14.7411154429

# %%
print('No of persons having zero followers are' ,sum(np.array(indegree_dist)==0),'and % is',
                                sum(np.array(indegree_dist)==0)*100/len(indegree_dist) )
# Out:
# No of persons having zero followers are 188043 and % is 10.0977865129

# %%
count=0
for i in g.nodes():
    if len(list(g.predecessors(i)))==0 :
        if len(list(g.successors(i)))==0:
            count+=1
print('No of persons those are not not following anyone and also not having any followers are',count)
# Out:
# No of persons those are not not following anyone and also not having any followers are 0

# %% [markdown]
# ## 1.3 both followers + following

# %%
from collections import Counter#prepares a dictionary with elements as keys and number of tie they occcur as the values
dict_in = dict(g.in_degree())
dict_out = dict(g.out_degree())
d = Counter(dict_in) + Counter(dict_out)
#this prepares the whole dictionary with number of followers and number of people that a user follow
in_out_degree = np.array(list(d.values()))
#sum of indegree and outdegree of a node is called its degree

# %%
in_out_degree_sorted = sorted(in_out_degree)
sns.set_style('darkgrid')
plt.figure(figsize = (15,6))
plt.plot(in_out_degree_sorted)
plt.xlabel('Index number',fontsize=15)
plt.ylabel('Number of people a user follows+ follwers',fontsize=15)
plt.show()

# %%
in_out_degree_sorted = sorted(in_out_degree)
sns.set_style('darkgrid')
plt.figure(figsize = (15,6))
plt.plot(in_out_degree_sorted[0:1500000])
plt.xlabel('Index number',fontsize=15)
plt.ylabel('Number of people a user follows+ follwers',fontsize=15)
plt.show()

# %%
### 90-100 percentile
for i in range(0,11):
    print(90+i,'percentile value is',np.percentile(in_out_degree_sorted,90+i))
# Out:
# 90 percentile value is 24.0
# 91 percentile value is 26.0
# 92 percentile value is 28.0
# 93 percentile value is 31.0
# 94 percentile value is 33.0
# 95 percentile value is 37.0
# 96 percentile value is 41.0
# 97 percentile value is 48.0
# 98 percentile value is 58.0
# 99 percentile value is 79.0
# 100 percentile value is 1579.0

# %%
### 99-100 percentile
for i in range(10,110,10):
    print(99+(i/100),'percentile value is',np.percentile(in_out_degree_sorted,99+(i/100)))
# Out:
# 99.1 percentile value is 83.0
# 99.2 percentile value is 87.0
# 99.3 percentile value is 93.0
# 99.4 percentile value is 99.0
# 99.5 percentile value is 108.0
# 99.6 percentile value is 120.0
# 99.7 percentile value is 138.0
# 99.8 percentile value is 168.0
# 99.9 percentile value is 221.0
# 100.0 percentile value is 1579.0

# %%
print('Min of no of followers + following is',in_out_degree.min())
print(np.sum(in_out_degree==in_out_degree.min()),' persons having minimum no of followers + following')
# Out:
# Min of no of followers + following is 1
# 334291  persons having minimum no of followers + following

# %%
print('Max of no of followers + following is',in_out_degree.max())
print(np.sum(in_out_degree==in_out_degree.max()),' persons having maximum no of followers + following')
# Out:
# Max of no of followers + following is 1579
# 1  persons having maximum no of followers + following

# %%
print('No of persons having followers + following less than 10 are',np.sum(in_out_degree<10))
# Out:
# No of persons having followers + following less than 10 are 1320326

# %%
print('No of weakly connected components',len(list(nx.weakly_connected_components(g))))
count=0
for i in list(nx.weakly_connected_components(g)):
    if len(i)==2:
        count+=1
print('weakly connected components wit 2 nodes',count)
# Out:
# No of weakly connected components 45558
# weakly connected components wit 2 nodes 32195

# %% [markdown]
# # 2. Posing a problem as classification problem

# %% [markdown]
# ## 2.1 Generating some edges which are not present in graph for supervised learning
#
# - As in the training data we have information about only those nodes who have a directed edge between them,not about nodes not having any edges between them.So to pose this as a classification problem we need to add all those nodes and add their label as '0'

# %%
# %%time
###generating bad edges from given graph
import random
if not os.path.isfile('after_eda/missing_edges_final.p'):
    #getting all set of edges
    r = csv.reader(open('after_eda/train_woheader.csv','r'))#opening the saved file from csv reader to read
    edges = dict()
    for edge in r:
        edges[(edge[0], edge[1])] = 1
#edges create a dictionary where key is pair of nodes as in training data and values as 1      
        
    missing_edges = set([])
    while (len(missing_edges)<9437519):#we want to add equal number of nodes which have missing edges
        a=random.randint(1, 1862220)
        #generating two random integers between 1 and total number of nodes
        b=random.randint(1, 1862220)
        
        tmp = edges.get((a,b),-1)#returns -1 if there do not exists any edge between specified nodes
        if tmp == -1 and a!=b:
            try:
                if nx.shortest_path_length(g,source=a,target=b) > 2: 
#here we are setting the threshhold  as shortest path to be greater than 2 because less than 2 will have very high chance of being followed or follower
                    missing_edges.add((a,b))
                else:
                    continue  
            except:  
                    missing_edges.add((a,b))              
        else:
            continue
    pickle.dump(missing_edges,open('after_eda/missing_edges_final.p','wb'))#writing the file
else:
    missing_edges = pickle.load(open('after_eda/missing_edges_final.p','rb'))#reading the file
# Out:
# Wall time: 7.18 s

# %%
len(missing_edges)
# Out:
# 9437519

# %% [markdown]
# ## 2.2 Training and Test data split:
# As we do not have the information about time in data,because data is of a particular timestap 't'.That's why we will be performing random splitting

# %%
from sklearn.model_selection import train_test_split
if (not os.path.isfile('after_eda/train_pos_after_eda.csv')) and (not os.path.isfile('after_eda/test_pos_after_eda.csv')):
    #reading total data df
    df_pos = pd.read_csv('train.csv')
    df_neg = pd.DataFrame(list(missing_edges), columns=['source_node', 'destination_node'])
    
    print("Number of nodes in the graph with edges", df_pos.shape[0])
    print("Number of nodes in the graph without edges", df_neg.shape[0])
    
#Training and test split 
#Spiltted data into 80-20 percentage 
#positive links and negative links seperatly because we need positive training data only for creating graph 
#and for feature generation
    X_train_pos, X_test_pos, y_train_pos, y_test_pos  = train_test_split(df_pos,np.ones(len(df_pos)),test_size=0.2, random_state=9)
    X_train_neg, X_test_neg, y_train_neg, y_test_neg  = train_test_split(df_neg,np.zeros(len(df_neg)),test_size=0.2, random_state=9)
    
    print('='*60)
    print("Number of nodes in the train data graph with edges", X_train_pos.shape[0],"=",y_train_pos.shape[0])
    print("Number of nodes in the train data graph without edges", X_train_neg.shape[0],"=", y_train_neg.shape[0])
    print('='*60)
    print("Number of nodes in the test data graph with edges", X_test_pos.shape[0],"=",y_test_pos.shape[0])
    print("Number of nodes in the test data graph without edges", X_test_neg.shape[0],"=",y_test_neg.shape[0])

    #removing header and saving
    X_train_pos.to_csv('after_eda/train_pos_after_eda.csv',header=False, index=False)
    X_test_pos.to_csv('after_eda/test_pos_after_eda.csv',header=False, index=False)
    X_train_neg.to_csv('after_eda/train_neg_after_eda.csv',header=False, index=False)
    X_test_neg.to_csv('after_eda/test_neg_after_eda.csv',header=False, index=False)
else:
    #Graph from Traing data only 
    del missing_edges

# %%
if (os.path.isfile('after_eda/train_pos_after_eda.csv')) and (os.path.isfile('after_eda/test_pos_after_eda.csv')):        
    train_graph=nx.read_edgelist('after_eda/train_pos_after_eda.csv',delimiter=',',create_using=nx.DiGraph(),nodetype=int)
    test_graph=nx.read_edgelist('after_eda/test_pos_after_eda.csv',delimiter=',',create_using=nx.DiGraph(),nodetype=int)
    #train graph is for training data points having edges
    #test graph is for test datapoints
    print(nx.info(train_graph))
    print(nx.info(test_graph))

    # finding the unique nodes in the both train and test graphs
    train_nodes_pos = set(train_graph.nodes())
    test_nodes_pos = set(test_graph.nodes())

    trY_teY = len(train_nodes_pos.intersection(test_nodes_pos))
    trY_teN = len(train_nodes_pos - test_nodes_pos)
    teY_trN = len(test_nodes_pos - train_nodes_pos)

    print('no of people common in train and test -- ',trY_teY)
    print('no of people present in train but not present in test -- ',trY_teN)

    print('no of people present in test but not present in train -- ',teY_trN)
    print(' % of people not there in Train but exist in Test in total Test data are {} %'.format(teY_trN/len(test_nodes_pos)*100))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 1780722
# Number of edges: 7550015
# Average in degree:   4.2399
# Average out degree:   4.2399
# Name:
# Type: DiGraph
# Number of nodes: 1144623
# Number of edges: 1887504
# Average in degree:   1.6490
# Average out degree:   1.6490
# no of people common in train and test --  1063125
# no of people present in train but not present in test --  717597
# no of people present in test but not present in train --  81498
#  % of people not there in Train but exist in Test in total Test data are 7.1200735962845405 %

# %% [markdown]
# > we have a cold start problem here

# %%
#final train and test data sets
if (not os.path.isfile('after_eda/train_after_eda.csv')) and \
(not os.path.isfile('after_eda/test_after_eda.csv')) and \
(not os.path.isfile('train_y.csv')) and \
(not os.path.isfile('test_y.csv')) and \
(os.path.isfile('after_eda/train_pos_after_eda.csv')) and \
(os.path.isfile('after_eda/test_pos_after_eda.csv')) and \
(os.path.isfile('after_eda/train_neg_after_eda.csv')) and \
(os.path.isfile('after_eda/test_neg_after_eda.csv')):
    
    X_train_pos = pd.read_csv('after_eda/train_pos_after_eda.csv', names=['source_node', 'destination_node'])
    X_test_pos = pd.read_csv('after_eda/test_pos_after_eda.csv', names=['source_node', 'destination_node'])
    X_train_neg = pd.read_csv('after_eda/train_neg_after_eda.csv', names=['source_node', 'destination_node'])
    X_test_neg = pd.read_csv('after_eda/test_neg_after_eda.csv', names=['source_node', 'destination_node'])

    print('='*60)
    print("Number of nodes in the train data graph with edges", X_train_pos.shape[0])
    print("Number of nodes in the train data graph without edges", X_train_neg.shape[0])
    print('='*60)
    print("Number of nodes in the test data graph with edges", X_test_pos.shape[0])
    print("Number of nodes in the test data graph without edges", X_test_neg.shape[0])

    X_train = X_train_pos.append(X_train_neg,ignore_index=True)
    y_train = np.concatenate((y_train_pos,y_train_neg))
    X_test = X_test_pos.append(X_test_neg,ignore_index=True)
    y_test = np.concatenate((y_test_pos,y_test_neg)) 
    
    X_train.to_csv('after_eda/train_after_eda.csv',header=False,index=False)
    X_test.to_csv('after_eda/test_after_eda.csv',header=False,index=False)
    pd.DataFrame(y_train.astype(int)).to_csv('train_y.csv',header=False,index=False)
    pd.DataFrame(y_test.astype(int)).to_csv('test_y.csv',header=False,index=False)
# Out:
# ...
# Number of nodes in the train data graph with edges 7550015
# Number of nodes in the train data graph without edges 7550015
# ...
# Number of nodes in the test data graph with edges 1887504
# Number of nodes in the test data graph without edges 1887504

# %%
print("Data points in train data",X_train.shape)
print("Data points in test data",X_test.shape)
print("Shape of traget variable in train",y_train.shape)
print("Shape of traget variable in test", y_test.shape)
# Out:
# Data points in train data (15100030, 2)
# Data points in test data (3775008, 2)
# Shape of traget variable in train (15100030,)
# Shape of traget variable in test (3775008,)
